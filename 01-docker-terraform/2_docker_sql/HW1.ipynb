# %%
import pandas as pd

# %%
from time import time

# %%
from sqlalchemy import create_engine

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
df = pd.read_csv('green_tripdata_2019-10.csv.gz', nrows = 100)

# %%
df
# Out:
#     VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0          2  2019-10-01 00:26:02   2019-10-01 00:39:58                  N
# 1          1  2019-10-01 00:18:11   2019-10-01 00:22:38                  N
# 2          1  2019-10-01 00:09:31   2019-10-01 00:24:47                  N
# 3          1  2019-10-01 00:37:40   2019-10-01 00:41:49                  N
# 4          2  2019-10-01 00:08:13   2019-10-01 00:17:56                  N
# ..       ...                  ...                   ...                ...
# 95         2  2019-10-01 00:02:53   2019-10-01 00:14:32                  N
# 96         2  2019-10-01 00:18:45   2019-10-01 00:29:23                  N
# 97         2  2019-10-01 00:41:32   2019-10-01 00:52:51                  N
# 98         2  2019-10-01 00:36:54   2019-10-01 00:54:20                  N
# 99         2  2019-10-01 00:21:27   2019-10-01 00:26:59                  N
#
# ...

# %%
print(pd.io.sql.get_schema(df, name ="green_taxi_data"))
# Out:
# CREATE TABLE "green_taxi_data" (
# "VendorID" INTEGER,
#   "lpep_pickup_datetime" TEXT,
#   "lpep_dropoff_datetime" TEXT,
#   "store_and_fwd_flag" TEXT,
#   "RatecodeID" INTEGER,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "ehail_fee" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "payment_type" INTEGER,
#   "trip_type" INTEGER,
#   "congestion_surcharge" REAL
# )

# %%
pd.to_datetime(df.lpep_pickup_datetime)
# Out:
# 0    2019-10-01 00:26:02
# 1    2019-10-01 00:18:11
# 2    2019-10-01 00:09:31
# 3    2019-10-01 00:37:40
# 4    2019-10-01 00:08:13
#              ...
# 95   2019-10-01 00:02:53
# 96   2019-10-01 00:18:45
# 97   2019-10-01 00:41:32
# 98   2019-10-01 00:36:54
# 99   2019-10-01 00:21:27
# Name: lpep_pickup_datetime, Length: 100, dtype: datetime64[ns]

# %%
pd.to_datetime(df.lpep_dropoff_datetime)
# Out:
# 0    2019-10-01 00:39:58
# 1    2019-10-01 00:22:38
# 2    2019-10-01 00:24:47
# 3    2019-10-01 00:41:49
# 4    2019-10-01 00:17:56
#              ...
# 95   2019-10-01 00:14:32
# 96   2019-10-01 00:29:23
# 97   2019-10-01 00:52:51
# 98   2019-10-01 00:54:20
# 99   2019-10-01 00:26:59
# Name: lpep_dropoff_datetime, Length: 100, dtype: datetime64[ns]

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df, name ="green_taxi_data", con=engine))
# Out:
# CREATE TABLE green_taxi_data (
# 	"VendorID" BIGINT,
# 	lpep_pickup_datetime TEXT,
# 	lpep_dropoff_datetime TEXT,
# 	store_and_fwd_flag TEXT,
# 	"RatecodeID" BIGINT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	ehail_fee FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	payment_type BIGINT,
# 	trip_type BIGINT,
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_iter = pd.read_csv('green_tripdata_2019-10.csv.gz', iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
len(df)
# Out:
# 100000

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df.head(n=0).to_sql(name="green_taxi_data", con=engine, if_exists="replace")
# Out:
# 0

# %%
df.to_sql(name="green_taxi_data", con=engine, if_exists="replace")
# Out:
# 1000

# %%
try:
    for df in pd.read_csv('green_tripdata_2019-10.csv.gz', iterator=True, chunksize=100000, encoding='latin1', low_memory=False):
        t_start = time()

        df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
        df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

        df.to_sql(name="green_taxi_data", con=engine, if_exists="append", index=False)

        t_end = time()
        elapsed_time = t_end - t_start
        print(f'inserted another chunk... took {elapsed_time:.3f} second')
    print("Data ingestion complete.")
except StopIteration:
    print("All data chunks processed successfully.")
# Out:
# inserted another chunk... took 6.698 second
# inserted another chunk... took 6.573 second
# inserted another chunk... took 6.568 second
# inserted another chunk... took 6.686 second
# inserted another chunk... took 4.423 second
# Data ingestion complete.
